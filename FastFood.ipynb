# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("FASTFOOD.csv")

# %%
df
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1  07-03-2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4           5  10-02-2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'date', 'item_name', 'item_type', 'item_price', 'quantity',
#        'transaction_amount', 'transaction_type', 'received_by',
#        'time_of_sale'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
plt.pie(pd.value_counts(df.item_type),labels=['Fastfood','Beverages'],autopct='%.1f%%')
plt.title('Item Type')
plt.legend()
plt.show()
# Out:
# C:\Users\adars\AppData\Local\Temp\ipykernel_18228\3655161715.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   plt.pie(pd.value_counts(df.item_type),labels=['Fastfood','Beverages'],autopct='%.1f%%')

# %%
sns.set(rc={'figure.figsize':(10,5)})
ax = sns.countplot(x='item_name',data=df,color='red')
for x in ax.containers:
    ax.bar_label(x)
plt.title('Item Name against count',fontsize =15)
# Out:
# Text(0.5, 1.0, 'Item Name against count')

# %%
sns.set(rc={'figure.figsize':(10,5)})
ax = sns.countplot(x='item_price',data = df,color='purple')
for x in ax.containers:
    ax.bar_label(x)
plt.title('Plot of Item price against the count')
# Out:
# Text(0.5, 1.0, 'Plot of Item price against the count')

# %%
plt.figure(figsize=(10,5))
plt.pie(
plt.title('Received By')
plt.legend()
plt.show()
# Out:
# C:\Users\adars\AppData\Local\Temp\ipykernel_18228\1487310106.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   plt.pie(pd.value_counts(df.received_by),labels=['Male','Female'],autopct='%.1f%%')

# %%
width =0.5
plt.figure(figsize = (10,5))
plt.bar(x1,y1,width)
plt.xlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %%
sns.displot(x='quantity',data=df,color='green')

# %%
plt.figure(figsize=(10,5))
e=[0.05,0.05,0.05,0.05,0.05]
plt.pie(pd.value_counts(df.time_of_sale),labels=['Morning','Afternoon','Evening','Night','Midnight'],explode=e,autopct='%.2f%%')
plt.show()
# Out:
# C:\Users\adars\AppData\Local\Temp\ipykernel_18228\2429263599.py:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   plt.pie(pd.value_counts(df.time_of_sale),labels=['Morning','Afternoon','Evening','Night','Midnight'],explode=e,autopct='%.2f%%')

# %%
plt.figure(figsize=(10,5))
plt.pie(pd.value_counts(df.transaction_type),labels=['Cash','Online'],autopct='%.2f%%')
plt.legend()
plt.show()
# Out:
# C:\Users\adars\AppData\Local\Temp\ipykernel_18228\3567872289.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   plt.pie(pd.value_counts(df.transaction_type),labels=['Cash','Online'],autopct='%.2f%%')

# %%
df.columns
# Out:
# Index(['order_id', 'date', 'item_name', 'item_type', 'item_price', 'quantity',
#        'transaction_amount', 'transaction_type', 'received_by',
#        'time_of_sale'],
#       dtype='object')

# %%
x1 = df['item_price'].tolist()
y1 = df['order_id'].tolist()
y2 = df['quantity'].tolist()
y3 = df['time_of_sale'].tolist()
plt.scatter(x1,y2,edgecolor='lightgreen',color='red',s=50)
plt.xlabel('Item Price')
plt.ylabel('Quantity')
plt.show()
